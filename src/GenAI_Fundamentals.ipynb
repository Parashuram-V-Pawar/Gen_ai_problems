# %% [markdown]
# # 🤖 Generative AI & Large Language Models (LLMs)
#
# ## Objectives
# In this notebook, you will learn:
# - What is Generative AI and LLMs
# - Transformer architecture & self-attention
# - BERT for text classification (Sentiment Analysis)
# - GPT for text generation
# - T5 for sequence-to-sequence tasks (Summarization)
# - Hugging Face ecosystem
# - Open-source LLMs
# - Prompt Engineering fundamentals & practice
# - Understanding model limitations (Hallucinations)

# %% [markdown]
# ## 🌱 What is Generative AI?
#
# Generative AI refers to models that can **generate new content**:
# - Text
# - Images
# - Code
# - Audio
#
# Unlike traditional ML (predict/classify), GenAI **creates**.
#
# ### Examples:
# - ChatGPT → text generation
# - DALL·E → image generation
# - GitHub Copilot → code completion

# %% [markdown]
# ## 🧠 Large Language Models (LLMs)
#
# LLMs are deep learning models trained on massive text corpora.
#
# Examples:
# - BERT → Understanding-focused
# - GPT → Generation-focused
# - T5 → Text-to-text framework
#
# Key properties:
# - Billions of parameters
# - Trained using self-supervised learning
# - Use Transformer architecture

# %% [markdown]
# ## 🔄 Transformer Architecture
#
# Transformers replaced RNNs/LSTMs by enabling:
# - Parallel processing
# - Long-range dependency capture
#
# ### Core Components:
# - Token Embeddings
# - Positional Encoding
# - Multi-Head Self-Attention
# - Feed Forward Networks

# %% [markdown]
# ## 👀 Attention Mechanism (Self-Attention)
#
# Self-attention allows each word to **attend to all other words**.
#
# It computes:
# - Query (Q)
# - Key (K)
# - Value (V)
#
# This helps the model understand **context** and **relationships**.

# %%
# !pip install transformers datasets sentencepiece accelerate
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.13.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.25.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.10.0+cpu)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.2.25)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.1.2)

# %% [markdown]
# ## 🤗 Hugging Face Ecosystem
#
# Key components:
# - `transformers` → Models & pipelines
# - `tokenizers` → Fast tokenization
# - `datasets` → Ready-to-use datasets
# - `hub` → Model sharing & versioning

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
from transformers import AutoModelForSeq2SeqLM, AutoModelForCausalLM

# %% [markdown]
# ## 🧩 BERT (Bidirectional Encoder Representations from Transformers)
#
# BERT is designed for **language understanding**:
# - Reads text bidirectionally
# - Excels at classification, NER, QA
#
# We will use BERT for **Sentiment Analysis**.

# %%
sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english"
)

sentiment_pipeline("The product quality is amazing and delivery was fast.")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9997946619987488}]

# %% [markdown]
# ## ✍️ GPT (Generative Pre-trained Transformer)
#
# GPT models are:
# - Autoregressive
# - Excellent at text generation & completion
#
# Used for:
# - Chatbots
# - Story writing
# - Code generation

# %%
generator = pipeline("text-generation", model="gpt2")

generator(
    "Artificial Intelligence will transform the future of",
    max_length=60,
    num_return_sequences=1
)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_length', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "Artificial Intelligence will transform the future of jobs and the lives of people around the world.\n\nThis is an open access article distributed under the terms of the Creative Commons Attribution License, which permits unrestricted use, distribution, and reproduction in any medium, provided the original author and source are credited.\n\nHemophilia has been implicated in more than 1,000 neurological disorders, including Parkinson's disease, Alzheimer's disease, amyotrophic lateral sclerosis, and Parkinson's disease. The risk of stroke and neurodegenerative diseases are increasing worldwide. In September 2015, a study published in the journal Lancet revealed that the number of people with hemophilia increased by 50 percent with each year of life, and that the risk of developing Alzheimer's could increase by 30 percent.\n\nMortality from stroke and other forms of neurological or psychiatric disorders has been falling in recent decades. In 2011, a study revealed that the incidence of stroke in adults aged 65 years and older increased by 40 percent in a series of studies. In addition, in 2012, a study published in the journal PLoS ONE revealed that the incidence of stroke in adults aged 65 years and older increased by 45 percent in a series of studies. In 2014, a study published in the journal Science reported that the incidence of stroke in adults aged 65 years and"}]

# %% [markdown]
# ## 🔁 T5 (Text-to-Text Transfer Transformer)
#
# T5 treats **every NLP task as text → text**:
# - Translation
# - Summarization
# - QA

# %%
summarizer = pipeline(
    "text-generation",
    model="t5-small"
)

text = """
summarize: Generative AI models have revolutionized the field of artificial intelligence by enabling machines to generate human-like text.
These models are widely used in chatbots, content generation, and search engines.
"""

summarizer(text, max_length=50, min_length=20)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/131 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# The model 'T5ForConditionalGeneration' is not supported for text-generation. Supported models are ['PeftModelForCausalLM', 'AfmoeForCausalLM', 'ApertusForCausalLM', 'ArceeForCausalLM', 'AriaTextForCausalLM', 'BambaForCausalLM', 'BartForCausalLM', 'BertLMHeadModel', 'BertGenerationDecoder', 'BigBirdForCausalLM', 'BigBirdPegasusForCausalLM', 'BioGptForCausalLM', 'BitNetForCausalLM', 'BlenderbotForCausalLM', 'BlenderbotSmallForCausalLM', 'BloomForCausalLM', 'BltForCausalLM', 'CamembertForCausalLM', 'LlamaForCausalLM', 'CodeGenForCausalLM', 'CohereForCausalLM', 'Cohere2ForCausalLM', 'CpmAntForCausalLM', 'CTRLLMHeadModel', 'CwmForCausalLM', 'Data2VecTextForCausalLM', 'DbrxForCausalLM', 'DeepseekV2ForCausalLM', 'DeepseekV3ForCausalLM', 'DiffLlamaForCausalLM', 'DogeForCausalLM', 'Dots1ForCausalLM', 'ElectraForCausalLM', 'Emu3ForCausalLM', 'ErnieForCausalLM', 'Ernie4_5ForCausalLM', 'Ernie4_5_MoeForCausalLM', 'Exaone4ForCausalLM', 'FalconForCausalLM', 'FalconH1ForCausalLM', 'FalconMambaForCausalLM', 'FlexOlmoForCausalLM', 'FuyuForCausalLM', 'GemmaForCausalLM', 'Gemma2ForCausalLM', 'Gemma3ForConditionalGeneration', 'Gemma3ForCausalLM', 'Gemma3nForConditionalGeneration', 'Gemma3nForCausalLM', 'GitForCausalLM', 'GlmForCausalLM', 'Glm4ForCausalLM', 'Glm4MoeForCausalLM', 'Glm4MoeLiteForCausalLM', 'GotOcr2ForConditionalGeneration', 'GPT2LMHeadModel', 'GPT2LMHeadModel', 'GPTBigCodeForCausalLM', 'GPTNeoForCausalLM', 'GPTNeoXForCausalLM', 'GPTNeoXJapaneseForCausalLM', 'GptOssForCausalLM', 'GPTJForCausalLM', 'GraniteForCausalLM', 'GraniteMoeForCausalLM', 'GraniteMoeHybridForCausalLM', 'GraniteMoeSharedForCausalLM', 'HeliumForCausalLM', 'HunYuanDenseV1ForCausalLM', 'HunYuanMoEV1ForCausalLM', 'Jais2ForCausalLM', 'JambaForCausalLM', 'JetMoeForCausalLM', 'Lfm2ForCausalLM', 'Lfm2MoeForCausalLM', 'LlamaForCausalLM', 'Llama4ForCausalLM', 'Llama4ForCausalLM', 'LongcatFlashForCausalLM', 'MambaForCausalLM', 'Mamba2ForCausalLM', 'MarianForCausalLM', 'MBartForCausalLM', 'MegatronBertForCausalLM', 'MiniMaxForCausalLM', 'MiniMaxM2ForCausalLM', 'MinistralForCausalLM', 'Ministral3ForCausalLM', 'MistralForCausalLM', 'MixtralForCausalLM', 'MllamaForCausalLM', 'ModernBertDecoderForCausalLM', 'MoshiForCausalLM', 'MptForCausalLM', 'MusicgenForCausalLM', 'MusicgenMelodyForCausalLM', 'MvpForCausalLM', 'NanoChatForCausalLM', 'NemotronForCausalLM', 'OlmoForCausalLM', 'Olmo2ForCausalLM', 'Olmo3ForCausalLM', 'OlmoeForCausalLM', 'OpenAIGPTLMHeadModel', 'OPTForCausalLM', 'PegasusForCausalLM', 'PersimmonForCausalLM', 'PhiForCausalLM', 'Phi3ForCausalLM', 'Phi4MultimodalForCausalLM', 'PhimoeForCausalLM', 'PLBartForCausalLM', 'ProphetNetForCausalLM', 'Qwen2ForCausalLM', 'Qwen2MoeForCausalLM', 'Qwen3ForCausalLM', 'Qwen3MoeForCausalLM', 'Qwen3NextForCausalLM', 'RecurrentGemmaForCausalLM', 'ReformerModelWithLMHead', 'RemBertForCausalLM', 'RobertaForCausalLM', 'RobertaPreLayerNormForCausalLM', 'RoCBertForCausalLM', 'RoFormerForCausalLM', 'RwkvForCausalLM', 'SeedOssForCausalLM', 'SmolLM3ForCausalLM', 'SolarOpenForCausalLM', 'StableLmForCausalLM', 'Starcoder2ForCausalLM', 'TrOCRForCausalLM', 'VaultGemmaForCausalLM', 'WhisperForCausalLM', 'XGLMForCausalLM', 'XLMWithLMHeadModel', 'XLMRobertaForCausalLM', 'XLMRobertaXLForCausalLM', 'XLNetLMHeadModel', 'xLSTMForCausalLM', 'XmodForCausalLM', 'ZambaForCausalLM', 'Zamba2ForCausalLM'].
# Passing `generation_config` together with generation-related arguments=({'max_length', 'min_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': '\nsummarize: Generative AI models have revolutionized the field of artificial intelligence by enabling machines to generate human-like text.\nThese models are widely used in chatbots, content generation, and search engines.\n'}]

# %% [markdown]
# ## 📦 Pretrained Models Summary
#
# | Model | Best For |
# |------|---------|
# | BERT | Understanding, classification |
# | GPT | Text generation |
# | T5 | Seq-to-seq tasks |
#
# Using pretrained models saves:
# - Time
# - Compute
# - Data requirements

# %% [markdown]
# ## 🌍 Open-Source LLMs
#
# Examples:
# - LLaMA (Meta)
# - Mistral
# - Falcon
# - BLOOM
#
# Benefits:
# - Transparency
# - Custom fine-tuning
# - On-prem deployment

# %% [markdown]
# ## 🧠 Prompt Engineering
#
# Prompt engineering is the art of **designing effective inputs** for LLMs.
#
# Good prompts:
# - Are clear
# - Provide context
# - Specify format

# %% [markdown]
# ## 🎯 Prompting Techniques
#
# 1. **Zero-shot Prompting**
#    - No examples
#
# 2. **One-shot Prompting**
#    - One example
#
# 3. **Few-shot Prompting**
#    - Multiple examples

# %% [markdown]
# ## ⚠️ Model Limitations – Hallucinations
#
# LLMs may:
# - Generate incorrect facts
# - Sound confident but be wrong
#
# Mitigation:
# - Grounding with data
# - Retrieval-Augmented Generation (RAG)
# - Explicit constraints in prompts

# %% [markdown]
# ## 🤖 Popular LLM Providers
#
# - **OpenAI** → GPT-5.2, GPT-5.1
# - **Anthropic** → Claude Opus
# - **Google** → Gemini 3
#
# Each differs in:
# - Safety
# - Cost
# - Context length

# %% [markdown]
# ## 🧪 Prompt Engineering Practice (Groq)
#
# Use any Groq Model (API) to try:
#
# ### 1️⃣ Summarizing
# "Summarize the following text in 5 bullet points."
#
# Paragraph - When Percy Jackson gets an urgent distress call from his friend Grover, he immediately prepares for battle. He knows he will need his powerful demigod allies at his side, his trusty bronze sword Riptide, and… a ride from his mom.
#
# The demigods rush to the rescue to find that Grover has made an important discovery: two powerful half-bloods whose parentage is unknown. But that’s not all that awaits them. The titan lord Kronos has devised his most treacherous plot yet, and the young heroes have just fallen prey.
#
# They’re not the only ones in danger. An ancient monster has arisen — one rumored to be so powerful it could destroy Olympus — and Artemis, the only goddess who might know how to track it, is missing. Now Percy and his friends, along with the Hunters of Artemis, have only a week to find the kidnapped goddess and solve the mystery of the monster she was hunting. Along the way, they must face their most dangerous challenge yet: the chilling prophecy of the titan’s curse.
#
# ### 2️⃣ Inferring
# "What can be inferred about reader's sentiment?"
#
# ### 3️⃣ Transforming
# "Convert this paragraph into a movie script."
#
# ### 4️⃣ Expanding
# "Expand this idea into a detailed explanation."
#
# ### 5️⃣ Few-shot Example
# Provide 2 examples before asking the task.

# %% [markdown]
# **Summarize the following text in 5 bullet points.**

# %%
# !pip install google-genai
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.12/dist-packages (1.68.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.47.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.6.3)

# %%
from google import genai
import os

os.environ["GOOGLE_API_KEY"] = "AIzaSyDUZtC6u3q3cAcS0DSsKOv7hisdm4SXiCc"

client = genai.Client()

# for m in client.models.list():
#     print(m.name)

paragraph = """
When Percy Jackson gets an urgent distress call from his friend Grover, he immediately prepares for battle. He knows he will need his powerful demigod allies at his side, his trusty bronze sword Riptide, and… a ride from his mom.

The demigods rush to the rescue to find that Grover has made an important discovery: two powerful half-bloods whose parentage is unknown. But that’s not all that awaits them. The titan lord Kronos has devised his most treacherous plot yet, and the young heroes have just fallen prey.

They’re not the only ones in danger. An ancient monster has arisen — one rumored to be so powerful it could destroy Olympus — and Artemis, the only goddess who might know how to track it, is missing. Now Percy and his friends, along with the Hunters of Artemis, have only a week to find the kidnapped goddess and solve the mystery of the monster she was hunting. Along the way, they must face their most dangerous challenge yet: the chilling prophecy of the titan’s curse.
"""

prompt = f"Summarize the following text in 5 bullet points.: {paragraph}"

response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents=prompt
)

print(response.text)
# Out:
# Here is a summary in 5 bullet points:
#
# *   Percy Jackson and his demigod allies respond to an urgent distress call from Grover.
# *   They discover Grover has found two powerful half-bloods, but they quickly realize they've fallen into a treacherous plot by the titan lord Kronos.
# *   An ancient and incredibly powerful monster, capable of destroying Olympus, has arisen.
# *   Complicating their mission, Artemis, the only goddess who might know how to track the monster, has gone missing.
# *   Percy, his friends, and the Hunters of Artemis have one week to find the kidnapped goddess, solve the monster mystery, and confront the chilling prophecy of the titan's curse.

# %% [markdown]
# **Inferring**

# %%
from google import genai
import os

os.environ["GOOGLE_API_KEY"] = "AIzaSyC0DY6tHpo8GneAujaZ1Dn8YgG80YPI8s8"

client = genai.Client()

prompt = f"What can be inferred about the reader's sentiment?: {paragraph}"
response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents=prompt
)

print(response.text)
# Out:
# The reader is likely to feel a strong sense of **excitement and anticipation** for the adventure, mixed with **apprehension and concern** for the characters' safety due to the escalating dangers.
#
# Here's a breakdown of the specific sentiments:
#
# *   **Excitement/Anticipation:** The mention of "prepares for battle," "powerful demigod allies," "trusty bronze sword," and a "most dangerous challenge yet" builds a sense of thrilling adventure.
# *   **Apprehension/Concern:** The "urgent distress call," "treacherous plot," heroes falling "prey," "ancient monster" that could "destroy Olympus," "Artemis is missing," and the "chilling prophecy" all create a feeling of dread and worry for the protagonists.
# *   **Urgency/Suspense:** The "only a week" time limit and the many unfolding mysteries ("unknown parentage," "solve the mystery of the monster") generate a strong desire to know what happens next.
# *   **Intrigue/Curiosity:** The introduction of new half-bloods, Kronos's plot, the ancient monster, and the "chilling prophecy" all provoke questions and a desire for answers.
# *   **Amusement/Fondness:** The detail "and… a ride from his mom" adds a touch of relatable humor and grounds the fantastical elements, likely eliciting a smile or chuckle from a reader familiar with the series' tone.
#
# Overall, the reader is being hooked with high stakes, immediate danger, and a compelling mystery, making them eager to delve into the story.

# %% [markdown]
# **Transforming**

# %%
os.environ["GOOGLE_API_KEY"] = "AIzaSyCpKyUeEYwQkAQZqQ9Mqd_MMJp5FPHtFhI"

client = genai.Client()

prompt = f"Convert this paragraph into a movie script. {paragraph}"
response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents=prompt
)

print(response.text)
# Out:
# Okay, here's a movie script based on your paragraph, focusing on setting the scene and launching the story.
#
# ---
#
# **TITLE: PERCY JACKSON AND THE TITAN'S CURSE**
#
# **LOGLINE:** When his satyr friend Grover sends a desperate plea, Percy Jackson rallies his demigod allies to uncover a treacherous plot by Kronos, save two powerful new half-bloods, and find a missing goddess before an ancient monster destroys Olympus.
#
# ---
#
# **SCENE 1**
#
# **INT. PERCY JACKSON'S APARTMENT - DAY**
#
# SOUND of video game, distant city traffic
#
# PERCY JACKSON (14, shaggy black hair, green eyes) is slumped on his bed, earbuds in, controller in hand. He's battling a digital dragon, utterly engrossed. A half-eaten blue cookie sits on his nightstand.
#
# Suddenly, his phone, resting beside the cookie, begins to VIBRATE violently. Not a normal vibrate – it almost hums with energy, a faint golden light shimmering from the screen.
#
# Percy pulls out an earbud, confused. He picks up the phone. The screen flickers, then resolves into a blurry, panicked image of GROVER UNDERWOOD (14, satyr, disguised as a human teen), his face streaked with dirt, his eyes wide with fear.
#
# <center>GROVER (O.S.)</center>
# > Percy! You have to—
#
# Static CRACKLES, distorting Grover's voice. The image wavers.
#
# <center>PERCY</center>
# > Grover? What is it? Where are you?
#
# <center>GROVER (O.S.)</center>
# > ...attacked! Two of them... new half-bloods... in danger! He's coming—
#
# A monstrous ROAR echoes through the phone. Grover's face twists in terror.
#
# <center>GROVER (O.S.)</center>
# > Kronos! It’s a trap, Percy! Get help!
#
# The connection dies. The screen goes black.
#
# Percy stares at the phone for a beat, the video game forgotten. His eyes narrow, the easygoing teen replaced by a warrior. He leaps off the bed.
#
# He snatches a ballpoint pen from his desk. It's an ordinary looking pen, but Percy grips it like a sacred weapon. This is RIPTIDE.
#
# He rushes to his bedroom door.
#
# <center>PERCY</center>
# > Mom! Emergency! Demigod stuff! I need a ride! Now!
#
# SALLY JACKSON (40s, warm but strong) appears in the doorway, a worried look on her face. She sees the pen in his hand, the grim set of his jaw. She knows.
#
# <center>SALLY</center>
# > Grab your backpack, honey. I’m already starting the car.
#
# Percy gives her a grateful, determined look and dashes back for his backpack.
#
# **EXT. URBAN ALLEYWAY - NIGHT**
#
# SOUND of distant sirens, struggling monsters, wind
#
# Percy, ANNABETH CHASE (14, blonde, gray eyes, fiercely intelligent), and CLARISSE LA RUE (16, burly, battle-scarred) sprint down a dark, grimy alley. Annabeth clutches a bronze dagger, Clarisse wields an electric spear.
#
# They slide to a halt at the alley's end, peering around a dumpster into a derelict, graffiti-covered loading dock.
#
# The scene is chaos. SPARKS fly. The metallic CLANG of weapons against monster scales. GROVER, looking bruised and battered, is barely holding off a pair of CYCLOPES, one protecting two terrified KIDS (a BOY and a GIRL, both around 12) huddled behind a shipping container.
#
# <center>PERCY</center>
# > Grover!
#
# Percy uncaps Riptide. It extends with a WHIRR, becoming a gleaming celestial bronze sword. Annabeth readies her dagger, Clarisse charges her spear.
#
# <center>ANNABETH</center>
# > Looks like we got here just in time.
#
# They charge into the fray. Percy slams into a Cyclops, parrying a clumsy blow. Annabeth slices expertly, drawing monster dust. Clarisse's spear crackles, making a Cyclops roar in pain.
#
# Grover, relieved, bleats nervously.
#
# <center>GROVER</center>
# > Percy! Annabeth! Oh, thank the gods! I found them—
#
# He gestures to the terrified kids, who flinch away from the battle.
#
# <center>GROVER</center>
# > ...two new half-bloods. Parentage unknown. They're powerful.
#
# Suddenly, a shimmering, dark energy barrier slams down, encircling the entire loading dock. The air grows cold. The monsters, momentarily disoriented, look up.
#
# <center>CLARISSE</center>
# > What the Hades?!
#
# A deep, resonating VOICE echoes from everywhere and nowhere, chilling them to the bone.
#
# <center>KRONOS (V.O.)</center>
# > Foolish demigods. You’ve walked directly into my trap.
#
# The Cyclopes turn, no longer attacking, but grinning maliciously. They lumber towards the shimmering barrier, *merging* with it, their forms dissipating as the barrier glows brighter, sealing them in.
#
# <center>ANNABETH</center>
# > Kronos! This wasn't just a rescue... it was a lure!
#
# The kids cower, whimpering. Percy, Grover, Annabeth, and Clarisse look around, trapped.
#
# **SCENE 2**
#
# **INT. CAMP HALF-BLOOD - CHIRON'S OFFICE - NIGHT**
#
# CHIRON (centaur, ancient, wise, wearing a tweed jacket over his horse half) stands before a large, ancient map of the world, pinned with strange symbols. Percy, Annabeth, and Grover (looking more shaken now) sit facing him. The two new half-bloods, still wary, stand uncertainly in a corner.
#
# <center>CHIRON</center>
# > Kronos’s treachery runs deeper than we imagined. The trap wasn't just to ensnare you, Percy. It was to activate something far more sinister.
#
# Chiron gestures to a symbol on the map – a swirling vortex over a remote, icy mountain range.
#
# <center>CHIRON</center>
# > An ancient evil has stirred. A creature of immense power, one whispered to be capable of destroying Olympus itself.
#
# He turns to them, his expression grave.
#
# <center>CHIRON</center>
# > And the one goddess who might know how to track it, who has been tirelessly pursuing it... Artemis... she is missing.
#
# Percy's eyes widen.
#
# <center>PERCY</center>
# > Artemis? Gone?
#
# <center>ANNABETH</center>
# > If Artemis is missing, that means the monster is truly dangerous. She wouldn't be caught off guard easily.
#
# <center>CHIRON</center>
# > Precisely. We have little time. The Oracle has spoken of this creature’s reawakening. You have one week. One week to find the kidnapped goddess and uncover the mystery of the monster she was hunting.
#
# A group of lean, formidable GIRLS and YOUNG WOMEN stand silently in the doorway, armed with bows and quivers. They wear silver parkas and have an intense, serious aura. These are THE HUNTERS OF ARTEMIS. Among them is ZOË NIGHTSHADE (15, dark hair, proud, unyielding), who meets Percy's gaze with disdain.
#
# <center>CHIRON</center>
# > You, Percy Jackson, Annabeth Chase, Grover Underwood... will go. And you will be joined by the Hunters of Artemis.
#
# Zoë snorts softly, giving Percy a withering look.
#
# <center>ZOË</center>
# > To travel with boys. How... delightful.
#
# <center>CHIRON</center>
# > (Ignoring her)
# > But heed this warning, young heroes. The journey will be perilous. The Oracle's prophecy, chilling and clear, speaks of...
#
# Chiron reaches for an old, leather-bound scroll on his desk, his voice dropping to a near whisper.
#
# <center>CHIRON</center>
# > ...The Titan’s Curse.
#
# Percy, Annabeth, and Grover exchange worried glances. The Hunters remain stoic, but even Zoë’s expression tightens. The weight of the quest settles upon them.
#
# **FADE OUT.**

# %% [markdown]
# **Expanding**

# %%
prompt = f"Expand this idea into a detailed explanation.: {paragraph}"
response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents=prompt
)

print(response.text)
# Out:
# Okay, let's expand that fantastic setup into a detailed narrative explanation, envisioning it as the thrilling plot of a new Percy Jackson adventure.
#
# ---
#
# ### **Percy Jackson and the Shadow of the Titan's Curse**
#
# The scent of saltwater and blue cookies usually brought Percy Jackson a sense of calm, but today, it was overshadowed by a primal dread. A frantic, staticky bleat from his conch shell, too strained and urgent to be anyone but Grover, had shattered his peaceful afternoon. No casual "what's up?" no familiar joke; just a desperate, garbled plea for help before the connection cut.
#
# **I. The Urgent Summons: "Mom, I Need a Ride to Save the World (Again)."**
#
# Percy didn't hesitate. His demigod instincts, honed through countless near-death experiences, screamed "danger." He didn't even need to be told. His hand instinctively went to his pocket, where Riptide, disguised as a humble ballpoint pen, felt heavier than usual. Preparing for battle wasn't just about grabbing his sword; it was a mental shift. He pictured his friends: Annabeth's calculating gaze, Grover's nervous but loyal energy, Thalia's electric defiance, Nico's shadowy presence. He knew he'd need their unique strengths, their unwavering loyalty.
#
# But first, the most crucial ally of all: his mom. Sally Jackson, with her calm demeanor and knowing smile, was perhaps the most formidable non-demigod in existence. She saw through the Mist, understood the precarious balance of his life, and knew implicitly when his "field trips" were anything but. "Trouble?" she'd asked, her hand already reaching for car keys as Percy burst into the living room, adrenaline thrumming. "Grover. Urgent." That was all she needed. Their blue Prius, a beacon of normalcy in a world of monsters and gods, would become their chariot of rescue. She was more than a chauffeur; she was a grounding force, a source of unwavering love that, in its own way, was as powerful as any divine blessing.
#
# **II. The Rescue, the Revelation, and Kronos's Treacherous Trap**
#
# The ride was a blur of New York traffic and Percy's growing anxiety. They found Grover not in a pitched battle as Percy had anticipated, but in a state of agitated awe in an abandoned, overgrown park on the city's outskirts. He was flanked by two teenagers, clearly half-bloods, radiating raw, untamed power that shimmered even to Percy's eyes. A girl with startlingly violet eyes and hair the color of midnight, her hands sparking with uncontrolled energy, and a boy with a wild mane of red hair, an unsettling calmness in his gaze, and an aura that seemed to subtly warp the air around him. Their parentage was a mystery, a potent blank slate that made Percy uneasy. They were *powerful*. Too powerful to have gone unnoticed this long.
#
# But before Percy could demand answers, the trap sprang. It wasn't a monster ambush, but something far more insidious. The ground beneath them didn't crack; it *shifted*, subtly altering their perceptions, their judgment. Illusions flickered at the edge of their vision, whispers echoed just out of hearing, and a chilling sense of dread settled over them. Kronos, the ultimate manipulator, hadn't sent an army; he'd cast a net of confusion and fear. Grover had discovered these powerful new half-bloods, yes, but that *was* the bait. The encounter was rigged, designed not to capture them immediately, but to disorient them, to push them onto a specific, dangerous path. They had just stumbled into a psychological maze, a prelude to a larger, more devastating plot.
#
# **III. The Ancient Terror and the Missing Goddess**
#
# Just as Percy, Annabeth (who had arrived shortly after Grover's call), and the others began to shake off the mental fog, a chilling message echoed through Grover's empathy link, originating not from him, but from an unseen source, laced with ancient power: "It awakens. Olympus falls."
#
# This was the true horror. An ancient monster, one not seen since the primordial ages, was stirring. Whispers of its name – perhaps the *Chthonic Maw* or the *World-Eater* – spoke of a being so vast and malevolent it could devour the very foundations of reality. It was a force of pure entropy, a primordial entity whose re-emergence threatened to unravel the very fabric of the world and dismantle the gods' dominion.
#
# And then, the second, equally devastating revelation: Artemis was missing. The goddess of the hunt, the wilderness, and the moon, was the only deity with the knowledge, the stealth, and the primal connection to track such an ancient beast. Her sudden disappearance was a terrifying void in their defensive line, suggesting a powerful force had managed to subdue even an Olympian. The very hunt she was on – presumably for this very monster – had now claimed her as its victim.
#
# **IV. The Quest Against Time: A Week to Save Olympus**
#
# Panic began to set in. Chiron, receiving the fragmented reports, convened an emergency council. With Artemis gone, her Hunters, led by her fiercely loyal lieutenants, arrived, their faces etched with grief and fury. They were mistrustful of male demigods, particularly Percy, but the gravity of the situation forced an uneasy alliance.
#
# The quest was clear, yet impossibly complex: In one short week, they had to locate the kidnapped goddess Artemis, unravel the mystery of the monstrous entity she was hunting, and somehow stop it before it reached Olympus. The fate of both the divine and mortal worlds hung in the balance.
#
# A desperate quest party was formed: Percy, Annabeth, Grover, Thalia (who was reluctantly permitted to join, given the urgency), and two of Artemis's most seasoned Hunters, Zoë Nightshade and Bianca di Angelo. The two mysterious new half-bloods, though powerful, were deemed too unstable or perhaps too compromised by Kronos's initial trap to be fully trusted, but their presence loomed as a wildcard.
#
# **V. The Chilling Prophecy of the Titan's Curse**
#
# As they prepared to depart, the Oracle of Delphi, her eyes glowing with an unearthly light, delivered a new prophecy, her voice rattling with the weight of ages:
#
# *Five shall go west to the goddess in chains,*
# *One shall be lost in the land without rain,*
# *The bane of Olympus shows the trail,*
# *Campers and Hunters united shall prevail,*
# *The Titan's curse must one endure,*
# *And one shall perish by a parent's lure.*
#
# The words hung heavy in the air, a shroud of dread. "The Titan's curse must one endure." This wasn't just about facing monsters; it was about internal struggle, unimaginable sacrifice, and the chilling possibility of betrayal or a loved one falling prey to the dark influence of their divine heritage. "And one shall perish by a parent's lure" sent shivers down Percy's spine, forcing him to consider the terrifying implications of their unknown enemy.
#
# Now, with a ticking clock, a primordial monster on the loose, a missing goddess, and a prophecy that promised heartbreak and death, Percy and his friends faced their most dangerous, most personal challenge yet. They were not just fighting for Olympus; they were fighting for each other, against a destiny woven by the cunning Kronos and the ancient forces of the universe itself. The adventure of "Percy Jackson and the Shadow of the Titan's Curse" had truly begun.

# %% [markdown]
# **Few-shot Example**

# %%
prompt = f"""
Example 1:
Text:
Harry receives a letter inviting him to Hogwarts School of Witchcraft and Wizardry.
He discovers that he is a wizard and makes friends with Ron and Hermione.
Together, they learn about the Sorcerer’s Stone and try to stop Voldemort
from stealing it.

Summary in 5 bullet points:
- Harry learns he is a wizard.
- He joins Hogwarts School.
- Harry becomes friends with Ron and Hermione.
- They discover the mystery of the Sorcerer’s Stone.
- They try to stop Voldemort from taking the Stone.

Example 2:
Text:
Katniss Everdeen volunteers to take her sister Prim’s place in the Hunger Games.
She travels to the Capitol with Peeta and must fight to survive in the deadly
competition. Along the way, she gains public support and challenges the rules
of the Games.

Summary in 5 bullet points:
- Katniss volunteers in place of her sister.
- She travels to the Capitol with Peeta.
- Katniss competes in the Hunger Games.
- She gains support from the audience.
- Katniss challenges the rules of the Games.

Now summarize the following text in 5 bullet points: {paragraph}
"""
response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents=prompt
)

print(response.text)
# Out:
# Summary in 5 bullet points:
# - Percy receives a distress call from Grover and prepares for battle.
# - They discover two new powerful half-bloods, but fall prey to Kronos's plot.
# - An ancient monster threatening Olympus has risen, and Artemis is missing.
# - Percy and his allies must find Artemis and the monster within a week.
# - They must also confront the prophecy of the titan's curse.

# %% [markdown]
# ## 🧠 Practice Exercises
#
# 1. Perform sentiment analysis on 5 customer reviews using BERT/Any Groq Model.
# 2. Generate a product description using Llama.
# 3. Summarize a news article using GPT-OSS.
# 4. Try zero-shot vs few-shot prompting and compare outputs.
# 5. Identify hallucinations in generated content.

# %% [markdown]
# **1. Perform sentiment analysis on 5 customer reviews using BERT/Any Groq Model.**

# %%
from transformers import pipeline

# %%
for m in client.models.list():
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/aqa
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/veo-3.1-lite-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025
# models/gemini-3.1-flash-live-preview

# %%
from transformers import pipeline

sentiment_pipeline = pipeline("sentiment-analysis")

reviews = [
    "Dhurandhar is a once in a lifetime movie.",
    "Very bad experience, waste of money.",
    "Adithya Dhar has made a fantastic movie.",
    "What a performance by ranveer singh he is once in a generation talent",
    "It is a propaganda movie."
]

results = sentiment_pipeline(reviews)

for review, result in zip(reviews, results):
    print(f"Review: {review}")
    print(f"Sentiment: {result['label']}")
    print("-"*50)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Review: Dhurandhar is a once in a lifetime movie.
# Sentiment: POSITIVE
# --------------------------------------------------
# Review: Very bad experience, waste of money.
# Sentiment: NEGATIVE
# --------------------------------------------------
# Review: Adithya Dhar has made a fantastic movie.
# Sentiment: POSITIVE
# --------------------------------------------------
# Review: What a performance by ranveer singh he is once in a generation talent
# Sentiment: POSITIVE
# --------------------------------------------------
# Review: It is a propaganda movie.
# Sentiment: NEGATIVE
# --------------------------------------------------

# %% [markdown]
# **2. Generate a product description using Llama.**

# %%
# !pip install groq
# Out:
# Collecting groq
#   Downloading groq-1.1.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-1.1.2-py3-none-any.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.7/141.7 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-1.1.2

# %%
from groq import Groq


client = Groq(
    api_key="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"
)

products = input("Enter product to generate description: ")

prompt = f"""
Provide me a description for the mentioned product : {products}

description must include:
- Key features
- target audience
- Benefits
"""

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role": "user", "content": prompt}]
)

print(response.choices[0].message.content)
# Out:
# Enter product to generate description: Psychology of money
# **Product Description: The Psychology of Money**
#
# **Book Overview:**
# The Psychology of Money is a self-help book written by Morgan Housel that explores the intersection of psychology and finance. The book delves into the ways in which our thoughts, emotions, and behaviors influence our financial decisions, and provides insights and strategies for improving our relationship with money.
#
# **Key Features:**
#
# * 19 short stories that illustrate how psychological concepts, such as cognitive biases and emotional influences, impact our financial decisions
# * Accessible and engaging storytelling that makes complex financial concepts easy to understand
# * Practical advice and takeaways for improving financial literacy and decision-making
# * Insights from history, psychology, and finance to provide a comprehensive understanding of the psychology of money
#
# **Target Audience:**
#
# * Individuals interested in personal finance and investing
# * Investors looking to improve their financial decision-making and risk management
# * Anyone seeking to understand the psychological factors that drive their financial behaviors
# * Professionals in the finance industry, such as financial advisors and wealth managers
# * Students of psychology, economics, and finance
#
# **Benefits:**
#
# * **Improved financial literacy**: The Psychology of Money provides readers with a deeper understanding of financial concepts and how they are influenced by psychological factors.
# * **Better financial decision-making**: By recognizing the psychological biases and emotions that drive our financial decisions, readers can make more informed and rational choices about their money.
# * **Increased financial confidence**: The book offers practical advice and strategies for managing risk, overcoming financial anxiety, and achieving long-term financial goals.
# * **Enhanced self-awareness**: The Psychology of Money encourages readers to reflect on their own financial values, goals, and behaviors, leading to a greater understanding of themselves and their relationship with money.
# * **Investing and wealth-building insights**: The book provides valuable insights and lessons from history, psychology, and finance that can help readers make more informed investment decisions and build long-term wealth.

# %% [markdown]
# **3. Summarize a news article using GPT-OSS.**

# %%
article = """
At first glance, Dhurandhar appears to be a fast-paced Bollywood spy thriller.
It features stylised action, strong performances, engaging soundtracks.
However, the film does more than just entertain. It has restarted an
uncomfortable conversation about terrorism, Pakistan’s underworld, and India’s
response to threats from beyond its borders. This Dhurandhar movie analysis
shows that the film’s impact goes beyond ticket sales. It has sparked strong
reactions online and in media discussions. Fans view it as a bold, well-made
film that doesn’t soften its ideological stance. Critics find it ‘high on
testosterone and gore’. What is clear is that Dhurandhar has changed the tone
of mainstream Hindi cinema.
"""

prompt = f"Summarize the following news article:\n{article}"

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role": "user", "content": prompt}]
)

print(response.choices[0].message.content)
# Out:
# The Bollywood film "Dhurandhar" appears to be an action-packed spy thriller at first, but it also sparks a deeper conversation about terrorism, Pakistan's underworld, and India's response to external threats. The film has received strong reactions, with fans praising its boldness and critics finding it overly violent and gory. Overall, "Dhurandhar" has made an impact that goes beyond entertainment, changing the tone of mainstream Hindi cinema.

# %% [markdown]
# **4. Try zero-shot vs few-shot prompting and compare outputs.**

# %%
from groq import Groq

client = Groq(api_key="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")

text = "Dhurandhar is a average movie many accross the world like it while some are oppsing it."


zero_shot_prompt = f"""
Classify sentiment (Positive, Negative, Neutral): "{text}"
"""

few_shot_prompt = f"""
Example:
Input: I love this product
Output: Positive

Input: This is terrible
Output: Negative

Input: It's okay, nothing special
Output: Neutral

Now classify:
Input: {text}
Output:
"""

# Function to get response
def get_response(prompt, model):
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content.strip()


models = [
    "llama-3.1-8b-instant"
]

for model in models:
    print(f"\n🔹 Model: {model}")

    zero_output = get_response(zero_shot_prompt, model)
    few_output = get_response(few_shot_prompt, model)

    print("Zero-shot Output :", zero_output)
    print("\nFew-shot Output  :", few_output)
    print("-" * 50)
# Out:
# 🔹 Model: llama-3.1-8b-instant
# Zero-shot Output : The sentiment of the statement can be classified as Neutral.
#
# The statement mentions that many people like the movie (positive aspect), but it also mentions that some people are opposing it (negative aspect). Since both positive and negative opinions are mentioned, the overall sentiment is neutral, as it does not lean heavily towards one side or the other.
#
# Few-shot Output  : Based on the given inputs and outputs, I would classify the given text as:
#
# Output: Neutral
#
# Explanation: The text contains both positive and negative opinions, but the overall tone seems to be balanced and neutral. The majority of people "like it" while some are opposing it, indicating a mixed reaction.
# --------------------------------------------------

# %% [markdown]
# **5. Identify hallucinations in generated content.**

# %% [markdown]
# There are no hallucinations in generated content as of now but we have some context changes where certain words have been miss interpreted but doesn't change the meaning of the statement.
